# %%
## download packages
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\shi.__.ling\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\shi.__.ling\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\shi.__.ling\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
## import libraries
import pandas as pd
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from imblearn.under_sampling import RandomUnderSampler
from imblearn.over_sampling import RandomOverSampler

# %%
## read the data
df_raw = pd.read_csv('../Data/Raw/Job_Frauds.csv', encoding='latin-1')

# %%
# inspect the data
df = df_raw
print(df.info())   # Check data types & missing values
print(df.head())   # View first few rows
print(df['Fraudulent'].value_counts())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17880 entries, 0 to 17879
# Data columns (total 16 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Job Title           17880 non-null  object
#  1   Job Location        17534 non-null  object
#  2   Department          6333 non-null   object
#  3   Range_of_Salary     2868 non-null   object
#  4   Profile             14572 non-null  object
#  5   Job_Description     17879 non-null  object
#  6   Requirements        15185 non-null  object
#  7   Job_Benefits        10670 non-null  object
#  8   Telecomunication    17880 non-null  int64
#  9   Comnpany_Logo       17880 non-null  int64
#  10  Type_of_Employment  14409 non-null  object
#  11  Experience          10830 non-null  object
#  12  Qualification       9775 non-null   object
#  13  Type_of_Industry    12977 non-null  object
#  14  Operations          11425 non-null  object
#  15  Fraudulent          17880 non-null  int64
# dtypes: int64(3), object(13)
# memory usage: 2.2+ MB
# None
#                                    Job Title        Job Location Department  \
# 0                           Marketing Intern    US, NY, New York  Marketing
# 1  Customer Service - Cloud Video Production      NZ, , Auckland    Success
# 2    Commissioning Machinery Assistant (CMA)       US, IA, Wever        NaN
# 3          Account Executive - Washington DC  US, DC, Washington      Sales
# 4                        Bill Review Manager  US, FL, Fort Worth        NaN
#
#   Range_of_Salary                                            Profile  \
# 0             NaN  We're Food52, and we've created a groundbreaki...
# 1             NaN  90 Seconds, the worlds Cloud Video Production ...
# 2             NaN  Valor Services provides Workforce Solutions th...
# 3             NaN  Our passion for improving quality of life thro...
# 4             NaN  SpotSource Solutions LLC is a Global Human Cap...
#
#                                      Job_Description  \
# 0  Food52, a fast-growing, James Beard Award-winn...
# 1  Organised - Focused - Vibrant - Awesome!Do you...
# 2  Our client, located in Houston, is actively se...
# 3  THE COMPANY: ESRI â Environmental Systems Re...
# 4  JOB TITLE: Itemization Review ManagerLOCATION:...
#
#                                         Requirements  \
# 0  Experience with content management systems a m...
# 1  What we expect from you:Your key responsibilit...
# 2  Implement pre-commissioning and commissioning ...
# 3  EDUCATION:Â Bachelorâs or Masterâs in GIS,...
# 4  QUALIFICATIONS:RN license in the State of Texa...
#
#                                         Job_Benefits  Telecomunication  \
# 0                                                NaN                 0
# 1  What you will get from usThrough being part of...                 0
# 2                                                NaN                 0
# 3  Our culture is anything but corporateâwe hav...                 0
# 4                              Full Benefits Offered                 0
#
#    Comnpany_Logo Type_of_Employment        Experience      Qualification  \
# 0              1              Other        Internship                NaN
# 1              1          Full-time    Not Applicable                NaN
# 2              1                NaN               NaN                NaN
# 3              1          Full-time  Mid-Senior level  Bachelor's Degree
# 4              1          Full-time  Mid-Senior level  Bachelor's Degree
#
#             Type_of_Industry            Operations  Fraudulent
# 0                        NaN             Marketing           0
# 1  Marketing and Advertising      Customer Service           0
# 2                        NaN                   NaN           0
# 3          Computer Software                 Sales           0
# 4     Hospital & Health Care  Health Care Provider           0
# 0    17014
# 1      866
# Name: Fraudulent, dtype: int64

# %%
# check for missing values
print(df.isnull().sum())
# Out:
# Job Title                 0
# Job Location            346
# Department            11547
# Range_of_Salary       15012
# Profile                3308
# Job_Description           1
# Requirements           2695
# Job_Benefits           7210
# Telecomunication          0
# Comnpany_Logo             0
# Type_of_Employment     3471
# Experience             7050
# Qualification          8105
# Type_of_Industry       4903
# Operations             6455
# Fraudulent                0
# dtype: int64

# %%
# check if missing values correlates with whether job is fraudulent
print(df[df['Department'].isnull()]['Fraudulent'].value_counts())
print(df[df['Range_of_Salary'].isnull()]['Fraudulent'].value_counts())
print(df[df['Profile'].isnull()]['Fraudulent'].value_counts())
print(df[df['Requirements'].isnull()]['Fraudulent'].value_counts())
print(df[df['Job_Benefits'].isnull()]['Fraudulent'].value_counts())
print(df[df['Type_of_Employment'].isnull()]['Fraudulent'].value_counts())
print(df[df['Experience'].isnull()]['Fraudulent'].value_counts())
print(df[df['Qualification'].isnull()]['Fraudulent'].value_counts())
print(df[df['Type_of_Industry'].isnull()]['Fraudulent'].value_counts())
print(df[df['Operations'].isnull()]['Fraudulent'].value_counts())
# Out:
# 0    11016
# 1      531
# Name: Fraudulent, dtype: int64
# 0    14369
# 1      643
# Name: Fraudulent, dtype: int64
# 0    2721
# 1     587
# Name: Fraudulent, dtype: int64
# 0    2541
# 1     154
# Name: Fraudulent, dtype: int64
# 0    6846
# 1     364
# Name: Fraudulent, dtype: int64
# 0    3230
# 1     241
# Name: Fraudulent, dtype: int64
# 0    6615
# 1     435
# Name: Fraudulent, dtype: int64
# 0    7654
# 1     451
# Name: Fraudulent, dtype: int64
# 0    4628
# 1     275
# Name: Fraudulent, dtype: int64
# 0    6118
# 1     337
# Name: Fraudulent, dtype: int64

# %%
# We can't simply drop missing vallues as they take up quite a significant portion of Fraudulant cases. 
# The presence of missing values may correlate with whether a job posting is fraudulent
# Have to check correlation when doing EDA/feature engineering

# %%
## split 'Job Location' into 'Country', 'State', 'City'
split_location = df['Job Location'].str.split(', ', expand=True)
df['Country'] = split_location[0]  
df['State'] = split_location[1] 
df['City'] = split_location[2] 
df = df.drop(columns=['Job Location'])

# %%
text_cols = ['Job Title','Profile', 'Job_Description', 'Requirements', 'Job_Benefits','Type_of_Employment','Experience','Qualification',
        'Department', 'Type_of_Industry', 'Operations','Country','State','City']
df[text_cols] = df[text_cols].fillna('unknown')

# %%
df.head()
# Out:
#                                    Job Title Department Range_of_Salary  \
# 0                           Marketing Intern  Marketing             NaN
# 1  Customer Service - Cloud Video Production    Success             NaN
# 2    Commissioning Machinery Assistant (CMA)    unknown             NaN
# 3          Account Executive - Washington DC      Sales             NaN
# 4                        Bill Review Manager    unknown             NaN
#
#                                              Profile  \
# 0  We're Food52, and we've created a groundbreaki...
# 1  90 Seconds, the worlds Cloud Video Production ...
# 2  Valor Services provides Workforce Solutions th...
# 3  Our passion for improving quality of life thro...
# 4  SpotSource Solutions LLC is a Global Human Cap...
#
#                                      Job_Description  \
# 0  Food52, a fast-growing, James Beard Award-winn...
# 1  Organised - Focused - Vibrant - Awesome!Do you...
# 2  Our client, located in Houston, is actively se...
# 3  THE COMPANY: ESRI â Environmental Systems Re...
# 4  JOB TITLE: Itemization Review ManagerLOCATION:...
#
#                                         Requirements  \
# 0  Experience with content management systems a m...
# 1  What we expect from you:Your key responsibilit...
# 2  Implement pre-commissioning and commissioning ...
# 3  EDUCATION:Â Bachelorâs or Masterâs in GIS,...
# 4  QUALIFICATIONS:RN license in the State of Texa...
#
#                                         Job_Benefits  Telecomunication  \
# 0                                            unknown                 0
# 1  What you will get from usThrough being part of...                 0
# 2                                            unknown                 0
# 3  Our culture is anything but corporateâwe hav...                 0
# 4                              Full Benefits Offered                 0
#
#    Comnpany_Logo Type_of_Employment        Experience      Qualification  \
# 0              1              Other        Internship            unknown
# 1              1          Full-time    Not Applicable            unknown
# 2              1            unknown           unknown            unknown
# 3              1          Full-time  Mid-Senior level  Bachelor's Degree
# 4              1          Full-time  Mid-Senior level  Bachelor's Degree
#
#             Type_of_Industry            Operations  Fraudulent Country State  \
# 0                    unknown             Marketing           0      US    NY
# 1  Marketing and Advertising      Customer Service           0      NZ
# 2                    unknown               unknown           0      US    IA
# 3          Computer Software                 Sales           0      US    DC
# 4     Hospital & Health Care  Health Care Provider           0      US    FL
#
#          City
# 0    New York
# 1    Auckland
# 2       Wever
# 3  Washington
# 4  Fort Worth

# %%
## convert strings to lower case
df = df.applymap(lambda x: x.lower() if isinstance(x, str) else x)

# %%
## remove punctuations and symbols
df = df.replace(to_replace=r'[^\w\s]', value='', regex=True)

# %%
## tokenize, remove stop words, and lemmatize for columns 'Profile', 'Job_Description', 'Requirements', 'Job_Benefits','Job Title', 'Department', 'Type_of_Industry', 'Operations'
# initialize stop words and lemmatizer

stop_words = set(stopwords.words('english'))
lemmatizer = WordNetLemmatizer()    
cols = ['Profile', 'Job_Description', 'Requirements', 'Job_Benefits','Job Title', 'Department', 'Type_of_Industry', 'Operations']

# %%
for col in cols:
    # apply tokenization 
    df[col] = df[col].apply(lambda x: word_tokenize(x) if isinstance(x, str) and x.strip() != '' else [])
    # remove stop words
    df[col] = df[col].apply(lambda x: [word for word in x if word not in stop_words])
    # apply lemmatization
    df[col] = df[col].apply(lambda x: [lemmatizer.lemmatize(word) for word in x])
    
print(df.head())
# Out:
#                                        Job Title   Department Range_of_Salary  \
# 0                            [marketing, intern]  [marketing]             NaN
# 1  [customer, service, cloud, video, production]    [success]             NaN
# 2     [commissioning, machinery, assistant, cma]    [unknown]             NaN
# 3           [account, executive, washington, dc]       [sale]             NaN
# 4                        [bill, review, manager]    [unknown]             NaN
#
#                                              Profile  \
# 0  [food52, weve, created, groundbreaking, awardw...
# 1  [90, second, world, cloud, video, production, ...
# 2  [valor, service, provides, workforce, solution...
# 3  [passion, improving, quality, life, geography,...
# 4  [spotsource, solution, llc, global, human, cap...
#
#                                      Job_Description  \
# 0  [food52, fastgrowing, james, beard, awardwinni...
# 1  [organised, focused, vibrant, awesomedo, passi...
# 2  [client, located, houston, actively, seeking, ...
# 3  [company, esri, â, environmental, system, rese...
# 4  [job, title, itemization, review, managerlocat...
#
#                                         Requirements  \
# 0  [experience, content, management, system, majo...
# 1  [expect, youyour, key, responsibility, communi...
# 2  [implement, precommissioning, commissioning, p...
# 3  [educationâ, bachelorâs, masterâs, gi, busines...
# 4  [qualificationsrn, license, state, texasdiplom...
#
#                                         Job_Benefits  Telecomunication  \
# 0                                          [unknown]                 0
# 1  [get, usthrough, part, 90, second, team, gaine...                 0
# 2                                          [unknown]                 0
# 3  [culture, anything, corporateâwe, collaborativ...                 0
# 4                           [full, benefit, offered]                 0
#
#    Comnpany_Logo Type_of_Employment       Experience     Qualification  \
# 0              1              other       internship           unknown
# 1              1           fulltime   not applicable           unknown
# 2              1            unknown          unknown           unknown
# 3              1           fulltime  midsenior level  bachelors degree
# 4              1           fulltime  midsenior level  bachelors degree
#
#            Type_of_Industry                Operations  Fraudulent Country  \
# 0                 [unknown]               [marketing]           0      us
# 1  [marketing, advertising]       [customer, service]           0      nz
# 2                 [unknown]                 [unknown]           0      us
# 3      [computer, software]                    [sale]           0      us
# 4  [hospital, health, care]  [health, care, provider]           0      us
#
#   State        City
# 0    ny    new york
# 1          auckland
# 2    ia       wever
# 3    dc  washington
# 4    fl  fort worth

# %%
for col in cols:
    df[col] = df[col].apply(lambda x: " ".join(x))
print(df.head())
# Out:
#                                  Job Title Department Range_of_Salary  \
# 0                         marketing intern  marketing             NaN
# 1  customer service cloud video production    success             NaN
# 2    commissioning machinery assistant cma    unknown             NaN
# 3          account executive washington dc       sale             NaN
# 4                      bill review manager    unknown             NaN
#
#                                              Profile  \
# 0  food52 weve created groundbreaking awardwinnin...
# 1  90 second world cloud video production service...
# 2  valor service provides workforce solution meet...
# 3  passion improving quality life geography heart...
# 4  spotsource solution llc global human capital m...
#
#                                      Job_Description  \
# 0  food52 fastgrowing james beard awardwinning on...
# 1  organised focused vibrant awesomedo passion cu...
# 2  client located houston actively seeking experi...
# 3  company esri â environmental system research i...
# 4  job title itemization review managerlocation f...
#
#                                         Requirements  \
# 0  experience content management system major plu...
# 1  expect youyour key responsibility communicate ...
# 2  implement precommissioning commissioning proce...
# 3  educationâ bachelorâs masterâs gi business adm...
# 4  qualificationsrn license state texasdiploma ba...
#
#                                         Job_Benefits  Telecomunication  \
# 0                                            unknown                 0
# 1  get usthrough part 90 second team gainexperien...                 0
# 2                                            unknown                 0
# 3  culture anything corporateâwe collaborative cr...                 0
# 4                               full benefit offered                 0
#
#    Comnpany_Logo Type_of_Employment       Experience     Qualification  \
# 0              1              other       internship           unknown
# 1              1           fulltime   not applicable           unknown
# 2              1            unknown          unknown           unknown
# 3              1           fulltime  midsenior level  bachelors degree
# 4              1           fulltime  midsenior level  bachelors degree
#
#         Type_of_Industry            Operations  Fraudulent Country State  \
# 0                unknown             marketing           0      us    ny
# 1  marketing advertising      customer service           0      nz
# 2                unknown               unknown           0      us    ia
# 3      computer software                  sale           0      us    dc
# 4   hospital health care  health care provider           0      us    fl
#
#          City
# 0    new york
# 1    auckland
# 2       wever
# 3  washington
# 4  fort worth

# %%
# check if data is imbalanced
print(df['Fraudulent'].value_counts())
# Out:
# 0    17014
# 1      866
# Name: Fraudulent, dtype: int64

# %%
# conduct undersampling since data is imbalanced
rus = RandomUnderSampler(random_state=0)
X_resampled, y_resampled = rus.fit_resample(df.drop(columns=['Fraudulent']), df['Fraudulent'])
df_uresampled = pd.concat([X_resampled, y_resampled], axis=1)
print(df_uresampled)
# Out:
#                                 Job Title      Department Range_of_Salary  \
# 13092       sr m dynamic consultant ax gp         unknown             NaN
# 13436           software engineer android         unknown             NaN
# 17502              twic rapidgate laborer         unknown             NaN
# 10820          agentinbound sale position         unknown        11501150
# 2067         internship medium production         unknown        45004500
# ...                                   ...             ...             ...
# 17827  student position parttime fulltime         unknown             NaN
# 17828                      sale associate  sale marketing             NaN
# 17829                   android developer         unknown             NaN
# 17830                       payroll clerk         unknown             NaN
# 17831                     furniture mover         unknown             NaN
#
#                                                  Profile  \
# 13092  eme international global leader enterprise mob...
# 13436  happy typing smart devicefleksy officially fas...
# 17502  elite environmental group llc provides staffin...
# 10820  delivering superior customer service 10 year i...
# 2067   initiative led talented energetic inspirationa...
# ...                                                  ...
# 17827                                            unknown
# 17828                                            unknown
# 17829                                            unknown
# 17830                                            unknown
# 17831  anthony warren marketing advertising consultan...
#
#                                          Job_Description  \
# 13092  implementing m dynamic product according m sur...
# 13436  fleksy next generation smart keyboard let type...
# 17502  environmental field workerlaborer responsible ...
# 10820  ibex global rapidly growing weâre looking quic...
# 2067   6month fulltime paid internship position large...
# ...                                                  ...
# 17827  student position parttime fulltimeyou home fre...
# 17828  learn earn executive level incomefull training...
# 17829  infullmobile sp z oo mobile software developme...
# 17830  job descriptionwe seeking full time payroll cl...
# 17831  earn 500 1000 week mover â must exp good lifti...
#
#                                             Requirements  \
# 13092  bachelor degree business accounting finance eq...
# 13436  successful candidate havea degree computer sci...
# 17502  qualified environmental field workerlaborer ha...
# 10820  call center sale representative driven succeed...
# 2067   bachelor degree major aei tei collegelimited w...
# ...                                                  ...
# 17827                                            unknown
# 17828  doâ â potential earn executive level income pa...
# 17829  â proven track record android java project c c...
# 17830  job requirementsââ â â high school diploma equ...
# 17831           good liftflexibile schedulegeat attitude
#
#                                             Job_Benefits  Telecomunication  \
# 13092                                            unknown                 0
# 13436  innovative keyboard company world currently ex...                 0
# 17502                                            unknown                 0
# 10820  benefitsâ offer employee following comprehensi...                 1
# 2067   working experience leading corporationsholisti...                 0
# ...                                                  ...               ...
# 17827                                            unknown                 0
# 17828  areâ global leadership development company ser...                 0
# 17829  attractive salary adequate candidate skillset ...                 0
# 17830  offer competitive salary benefit package inclu...                 0
# 17831                                            unknown                 0
#
#        Comnpany_Logo Type_of_Employment   Experience  \
# 13092              1           fulltime    associate
# 13436              1           fulltime    associate
# 17502              1           contract      unknown
# 10820              1           fulltime  entry level
# 2067               1           fulltime   internship
# ...              ...                ...          ...
# 17827              0           parttime      unknown
# 17828              0            unknown      unknown
# 17829              0            unknown      unknown
# 17830              0           fulltime      unknown
# 17831              1            unknown      unknown
#
#                    Qualification                Type_of_Industry  \
# 13092           bachelors degree  information technology service
# 13436           bachelors degree               computer software
# 17502                    unknown           environmental service
# 10820  high school or equivalent               telecommunication
# 2067            bachelors degree               medium production
# ...                          ...                             ...
# 17827                    unknown                         unknown
# 17828                    unknown                         unknown
# 17829                    unknown                         unknown
# 17830                    unknown                 apparel fashion
# 17831                    unknown                         unknown
#
#                    Operations Country State               City  Fraudulent
# 13092  information technology      eg     c              maadi           0
# 13436  information technology      us    ca      san francisco           0
# 17502                              us    ct           hartford           0
# 10820        customer service      us    pa  robinson township           0
# 2067              artcreative      gr                                    0
# ...                       ...     ...   ...                ...         ...
# 17827                 unknown      us    ca        los angeles           1
# 17828                 unknown      au   nsw             sydney           1
# 17829                 unknown      pl    mz             warsaw           1
# 17830      accountingauditing      us    ny           new york           1
# 17831                 unknown      us    il            chicago           1
#
# [1732 rows x 18 columns]
# c:\Users\shi.__.ling\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:484: FutureWarning: `BaseEstimator._check_n_features` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation._check_n_features` instead.
#   warnings.warn(
# c:\Users\shi.__.ling\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: FutureWarning: `BaseEstimator._check_feature_names` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation._check_feature_names` instead.
#   warnings.warn(

# %%
# conduct oversampling since data is imbalanced
ros = RandomOverSampler(random_state=0)
X_resampled, y_resampled = ros.fit_resample(df.drop(columns=['Fraudulent']), df['Fraudulent'])
df_oresampled = pd.concat([X_resampled, y_resampled], axis=1)
print(df_oresampled)
# Out:
#                                      Job Title   Department Range_of_Salary  \
# 0                             marketing intern    marketing             NaN
# 1      customer service cloud video production      success             NaN
# 2        commissioning machinery assistant cma      unknown             NaN
# 3              account executive washington dc         sale             NaN
# 4                          bill review manager      unknown             NaN
# ...                                        ...          ...             ...
# 34023                              hse manager      unknown             NaN
# 34024                      final expense agent      unknown             NaN
# 34025       nursing therapy position home care      unknown             NaN
# 34026       home based typist data entry clerk      unknown             NaN
# 34027         product development engineer plc  engineering    120000180000
#
#                                                  Profile  \
# 0      food52 weve created groundbreaking awardwinnin...
# 1      90 second world cloud video production service...
# 2      valor service provides workforce solution meet...
# 3      passion improving quality life geography heart...
# 4      spotsource solution llc global human capital m...
# ...                                                  ...
# 34023  aker solution global provider product system s...
# 34024                                            unknown
# 34025                                            unknown
# 34026                                            unknown
# 34027  aptitude staffing solution redesigned recruiti...
#
#                                          Job_Description  \
# 0      food52 fastgrowing james beard awardwinning on...
# 1      organised focused vibrant awesomedo passion cu...
# 2      client located houston actively seeking experi...
# 3      company esri â environmental system research i...
# 4      job title itemization review managerlocation f...
# ...                                                  ...
# 34023  corporate overviewaker solution global provide...
# 34024  normal 0 false false false enus xnone xnone st...
# 34025  nursing amp therapy positionshome carenbspnbsp...
# 34026  several opening available area offering compet...
# 34027  â product development engineer plc taiwanwork ...
#
#                                             Requirements  \
# 0      experience content management system major plu...
# 1      expect youyour key responsibility communicate ...
# 2      implement precommissioning commissioning proce...
# 3      educationâ bachelorâs masterâs gi business adm...
# 4      qualificationsrn license state texasdiploma ba...
# ...                                                  ...
# 34023  qualification amp personal attributesâ experie...
# 34024                             life insurance license
# 34025                                            unknown
# 34026  applicant computer internet access basic compu...
# 34027  skill requirementsâ least 5 year plc hardware ...
#
#                                             Job_Benefits  Telecomunication  \
# 0                                                unknown                 0
# 1      get usthrough part 90 second team gainexperien...                 0
# 2                                                unknown                 0
# 3      culture anything corporateâwe collaborative cr...                 0
# 4                                   full benefit offered                 0
# ...                                                  ...               ...
# 34023  offerâ friendly colleague industry bright futu...                 0
# 34024                                            unknown                 0
# 34025                                            unknown                 0
# 34026  averaging r2500 per week depending working par...                 0
# 34027  offeredvery competitive base salarysignificant...                 0
#
#        Comnpany_Logo Type_of_Employment       Experience     Qualification  \
# 0                  1              other       internship           unknown
# 1                  1           fulltime   not applicable           unknown
# 2                  1            unknown          unknown           unknown
# 3                  1           fulltime  midsenior level  bachelors degree
# 4                  1           fulltime  midsenior level  bachelors degree
# ...              ...                ...              ...               ...
# 34023              1           fulltime          unknown           unknown
# 34024              0            unknown          unknown           unknown
# 34025              0            unknown          unknown           unknown
# 34026              0            unknown          unknown           unknown
# 34027              1           fulltime  midsenior level  bachelors degree
#
#             Type_of_Industry            Operations Country State        City  \
# 0                    unknown             marketing      us    ny    new york
# 1      marketing advertising      customer service      nz          auckland
# 2                    unknown               unknown      us    ia       wever
# 3          computer software                  sale      us    dc  washington
# 4       hospital health care  health care provider      us    fl  fort worth
# ...                      ...                   ...     ...   ...         ...
# 34023             oil energy           engineering      us    tx     houston
# 34024              insurance               unknown      us
# 34025                unknown               unknown      us
# 34026                unknown               unknown      za    wc  oudtshoorn
# 34027    computer networking           engineering      tw   tpq      taipei
#
#        Fraudulent
# 0               0
# 1               0
# 2               0
# 3               0
# 4               0
# ...           ...
# 34023           1
# 34024           1
# 34025           1
# 34026           1
# 34027           1
#
# [34028 rows x 18 columns]
# c:\Users\shi.__.ling\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:484: FutureWarning: `BaseEstimator._check_n_features` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation._check_n_features` instead.
#   warnings.warn(
# c:\Users\shi.__.ling\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: FutureWarning: `BaseEstimator._check_feature_names` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation._check_feature_names` instead.
#   warnings.warn(

# %%
## save as csv
df.to_csv('../Data/Processed/processed_df.csv', index=False)
